# %% [markdown]
# # 02 — Chunking EDA
#
# Analyse chunk size distribution and quality after splitting actuarial documents.

# %%
import sys
sys.path.insert(0, '..')

import pandas as pd
import matplotlib.pyplot as plt
from src.ingestion.loader import load_document
from src.ingestion.chunker import chunk_text
